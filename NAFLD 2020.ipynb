# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filepath= '~/Desktop/IISc/Tools/RACIPE-1.0/NAFLD 2020.csv'
df= pd.read_csv(filepath)

# %%
df
# Out:
#     TS_Solution File Number   Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                          2   -1.552101   -1.135206    0.960181    0.746445
# 1                          3    0.248084    0.039919   -0.236681   -1.397921
# 2                          3    1.280440    1.250846   -1.325092   -0.332237
# 3                          3   -1.341800   -0.789151    1.543100    1.418987
# 4                          3   -1.716051    0.040982    1.218406    1.578243
# ..                       ...         ...         ...         ...         ...
# 95                         3    1.079171    0.868212   -1.707438   -1.261621
# 96                         2    2.280498    0.414845   -0.591473   -0.546830
# 97                         3    1.393394    1.307132   -1.736510    0.076660
# 98                         4   -1.709166   -1.571683    1.454885    0.915234
# 99                         3   -0.669849   -0.510736    1.172787    1.212892
#
#     Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0     0.898090    0.806027   -0.591106   -0.132330         NaN  ...
# 1     1.174418    1.793960   -1.178318   -1.397922    0.248084  ...
# 2    -1.193021   -0.527303    1.010694    1.517147   -0.112175  ...
# 3    -0.565798   -0.789151   -0.070772   -0.531062    0.955642  ...
# 4    -0.818458    0.041391   -0.622431   -0.421006    0.965783  ...
# ..         ...         ...         ...         ...         ...  ...
# 95   -1.136698   -1.077320    0.655540    0.533317    0.607804  ...
# 96    0.138729   -0.580442   -0.568497   -0.546830         NaN  ...
# 97   -1.028740   -0.377345    0.649792    1.212301   -0.240149  ...
# 98    0.430920   -0.711047    0.957615   -0.507272    0.963211  ...
# 99    1.515147    1.179805   -1.585528   -0.398240   -0.223527  ...
#
#     Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# ..          ...          ...          ...          ...          ...
# 95          NaN          NaN          NaN          NaN          NaN
# 96          NaN          NaN          NaN          NaN          NaN
# 97          NaN          NaN          NaN          NaN          NaN
# 98     -0.94142    -1.086951          NaN          NaN          NaN
# 99          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# ..          ...          ...          ...          ...          ...
# 95          NaN          NaN          NaN          NaN          NaN
# 96          NaN          NaN          NaN          NaN          NaN
# 97          NaN          NaN          NaN          NaN          NaN
# 98          NaN          NaN          NaN          NaN          NaN
# 99          NaN          NaN          NaN          NaN          NaN
#
# [100 rows x 25 columns]

# %%
df.dtypes

# %%
print(df.isnull().any())

# %%
unique_train=pd.DataFrame([(col,df[col].nunique()) for col in df.columns],
                columns=['Columns', 'Unique categories'])
unique_train=unique_train[1:]
fig, ax = plt.subplots(2, 1, sharex=True, sharey=True)
ax[0].bar(unique_train.Columns, unique_train['Unique categories'])
plt.xticks(rotation=90)

sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df.columns
# Out:
# Index(['TS_Solution File Number ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24'],
#       dtype='object')

# %%
arr1=[]
arr2=[]
arr3=[]
arr4=[]
arr5=[]
arr6=[]
for j in range(1,100):
    if df.iloc[j,0]==1:
        for i in range(1,25):
            arr1.append(df.iloc[j,i])
    elif df.iloc[j,0]==2:
        for i in range(1,25):
            arr2.append(df.iloc[j,i])
    elif df.iloc[j,0]==3:
        for i in range(1,25):
            arr3.append(df.iloc[j,i])
    elif df.iloc[j,0]==4:
        for i in range(1,25):
            arr4.append(df.iloc[j,i])
    elif df.iloc[j,0]==5:
        for i in range(1,25):
            arr5.append(df.iloc[j,i])
    elif df.iloc[j,0]==6:
        for i in range(1,25):
            arr6.append(df.iloc[j,i])

# %%
s1=pd.Series(arr1)
s2=pd.Series(arr2)
s3=pd.Series(arr3)
s4=pd.Series(arr4)
s5=pd.Series(arr5)
s6=pd.Series(arr6)

# %%
s1.plot.kde()
s2.plot.kde()
s3.plot.kde()
s4.plot.kde()
plt.legend(labels=['PPARG','HNF1A','SREBF1','HNF4A'])
